# %% [markdown]
# # Sparse Norm Inversion for Total Magnetic Intensity Data on a Tensor Mesh
#
# .. important::
#
#     This tutorial has been moved to [User Tutorials](https://simpeg.xyz/user-tutorials).
#
#     Checkout the [Iteratively Re-weighted Least-Squares Inversion](https://simpeg.xyz/user-tutorials/inv-magnetics-induced-3d/#iteratively-re-weighted-least-squares-inversion)
#     section of the [3D Inversion of TMI Data to Recover a Susceptibility Model Models](https://simpeg.xyz/user-tutorials/inv-magnetics-induced-3d/) tutorial.
