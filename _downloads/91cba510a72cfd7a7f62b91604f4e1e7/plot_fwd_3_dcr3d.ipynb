# %% [markdown]
# # DC Resistivity Forward Simulation in 3D
#
# .. important::
#
#     This tutorial has been moved to [User Tutorials](https://simpeg.xyz/user-tutorials).
#
#     Checkout the [3D Forward Simulation](https://simpeg.xyz/user-tutorials/fwd-dcr-3d/) tutorial.
