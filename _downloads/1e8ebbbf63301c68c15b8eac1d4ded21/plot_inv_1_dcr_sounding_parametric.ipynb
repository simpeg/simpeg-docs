# %% [markdown]
# # Parametric 1D Inversion of Sounding Data
#
# .. important::
#
#     This tutorial has been moved to [User Tutorials](https://simpeg.xyz/user-tutorials).
#
#     Checkout the [Parametric Inversion](https://simpeg.xyz/user-tutorials/inv-dcr-1d/#parametric-inversion)
#     section in the
#     [1D Inversion for a Single Sounding](https://simpeg.xyz/user-tutorials/inv-dcr-1d/) tutorial.
