# %% [markdown]
# # Compare weighting strategy with Inversion of surface Gravity Anomaly Data
#
# .. important::
#
#     This tutorial has been moved to [User Tutorials](https://simpeg.xyz/user-tutorials).
#
#     Checkout the [Compare weighting strategy with Inversion of surface Gravity Anomaly
#     Data](https://simpeg.xyz/user-tutorials/weighting-strategies) tutorial.
