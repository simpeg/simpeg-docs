# %% [markdown]
# # Least-Squares Inversion of Gravity Anomaly Data
#
# .. important::
#
#     This tutorial has been moved to [User Tutorials](https://simpeg.xyz/user-tutorials).
#
#     Checkout the [3D Inversion of Gravity Anomaly Data](https://simpeg.xyz/user-tutorials/inv-gravity-anomaly-3d/) tutorial.
